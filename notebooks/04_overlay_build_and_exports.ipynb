# %% [markdown]
# # 04 Overlay Build and Exports
#
# Build overlay tables and write canonical contract exports.

# %%
import sys, pathlib
# Make the repo root importable whether run from repo root or notebooks/
_root = pathlib.Path.cwd()
if not (_root / 'src').exists() and (_root.parent / 'src').exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from src.export_contracts import export_contracts
outputs = export_contracts()
sorted(outputs.keys())
# Out:
# ['business_cycle_panel',
#  'downturn_overlay_table',
#  'industry_financial_benchmarks',
#  'industry_risk_scores',
#  'macro_regime_flags',
#  'property_cycle_panel',
#  'property_market_overlays',
#  'property_market_overlays_by_building_type']
