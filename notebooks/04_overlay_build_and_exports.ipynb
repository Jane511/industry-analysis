# %% [markdown]
# # 04 Overlay Build and Exports
#
# Build overlay tables and write canonical contract exports.

# %%
from scripts.export_contracts import export_contracts
outputs = export_contracts()
sorted(outputs.keys())
