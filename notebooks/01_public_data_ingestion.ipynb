# %% [markdown]
# # 01 Public Data Ingestion
#
# Covers canonical raw-data download and manual-load workflow.

# %%
import sys, pathlib
# Make the repo root importable whether run from repo root or notebooks/
_root = pathlib.Path.cwd()
if not (_root / 'src').exists() and (_root.parent / 'src').exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from src.download_public_data import download_public_data
download_public_data()
# Out:
# ...
# Target directory: D:\Jane\Job Search\Github\bank\github project\external benchmarks and industry analysis\industry-analysis\data\raw\public\ptrs
# Note: optional manual context extracts should be staged under data/raw/manual/.
# ...
# Saved PTRS public files to D:\Jane\Job Search\Github\bank\github project\external benchmarks and industry analysis\industry-analysis\data\raw\public\ptrs
# Rebuilt PTRS workbook -> PTRS_MultiCycle_AR_Days_Model_Official.xlsx
# WindowsPath('D:/Jane/Job Search/Github/bank/github project/external benchmarks and industry analysis/industry-analysis/data/raw/public/ptrs/PTRS_MultiCycle_AR_Days_Model_Official.xlsx')
