# %% [markdown]
# # 03 Property Cycle Panels
#
# Build and inspect property-cycle panel outputs.

# %%
import sys, pathlib
# Make the repo root importable whether run from repo root or notebooks/
_root = pathlib.Path.cwd()
if not (_root / 'src').exists() and (_root.parent / 'src').exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from src.panels.build_property_cycle_panel import build_property_cycle_panel
property_panel = build_property_cycle_panel()
property_panel.head()
# Out:
#       region                      property_segment  approvals_change_pct  \
# 0  Australia                               Offices                -35.72
# 1  Australia                   Education buildings                -21.37
# 2  Australia  Retail and wholesale trade buildings                 68.47
# 3  Australia    Short term accommodation buildings                113.70
# 4  Australia                  Aged care facilities                219.88
#
#          commencements_signal          completions_signal cycle_stage  \
# 0  Proxy from approvals trend  Proxy from approvals trend    downturn
# 1  Proxy from approvals trend  Proxy from approvals trend     slowing
# 2  Proxy from approvals trend  Proxy from approvals trend     neutral
# 3  Proxy from approvals trend  Proxy from approvals trend      growth
# 4  Proxy from approvals trend  Proxy from approvals trend     neutral
#
#    market_softness_score market_softness_band  as_of_date  \
# 0                   4.30                 High  2026-02-01
# 1                   3.25             Elevated  2026-02-01
# 2                   3.15             Elevated  2026-02-01
# 3                   2.85               Medium  2026-02-01
# 4                   2.70               Medium  2026-02-01
#
#                                          source_note  region_risk_score  \
# 0  ABS Building Approvals - Non-residential; buil...               4.03
# 1  ABS Building Approvals - Non-residential; buil...               3.38
# 2  ABS Building Approvals - Non-residential; buil...               2.95
# 3  ABS Building Approvals - Non-residential; buil...               2.55
# 4  ABS Building Approvals - Non-residential; buil...               2.73
#
#   region_risk_band
# 0             High
# 1         Elevated
# 2           Medium
# 3           Medium
# 4           Medium
