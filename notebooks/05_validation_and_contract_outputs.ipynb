# %% [markdown]
# # 05 Validation and Contract Outputs
#
# Run canonical export validation checks used before downstream handoff.

# %%
import sys, pathlib
# Make the repo root importable whether run from repo root or notebooks/
_root = pathlib.Path.cwd()
if not (_root / 'src').exists() and (_root.parent / 'src').exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from src.validate_upstream import validate_upstream
validate_upstream()
# Out:
#                                                          check_name  status  required_for_pass                                                                                                                                                                    detail
#                                   core_output::industry_risk_scores    True               True                                                                                                                                                     present and non-empty
#                          core_export_file::industry_risk_scores.csv    True               True                      D:\Jane\Job Search\Github\bank\github project\external benchmarks and industry analysis\industry-analysis\outputs\contracts\industry_risk_scores.csv
# ...
