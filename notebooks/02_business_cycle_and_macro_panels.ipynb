# %% [markdown]
# # 02 Business Cycle and Macro Panels
#
# Build and inspect the canonical business-cycle and macro-regime panel outputs.

# %%
import sys, pathlib
# Make the repo root importable whether run from repo root or notebooks/
_root = pathlib.Path.cwd()
if not (_root / 'src').exists() and (_root.parent / 'src').exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from src.panels.build_business_cycle_panel import build_business_cycle_panel
panel = build_business_cycle_panel()
panel.head()
# Out:
#                             sector_key anzsic_division_code  \
# 0      accommodation and food services                    H
# 1  administrative and support services                    N
# 2     agriculture forestry and fishing                    A
# 3         arts and recreation services                    R
# 4                         construction                    E
#
#                               industry            internal_grouping_example  \
# 0      Accommodation and Food Services              Hospitality and leisure
# 1  Administrative and Support Services  Administrative and support services
# 2    Agriculture, Forestry and Fishing  Primary production and agribusiness
# 3         Arts and Recreation Services         Arts and recreation services
# 4                         Construction   Building, civil and trade services
#
#    classification_risk_score  sales_m_latest  employment_000_latest  \
# 0                       2.75          152965                 1217.9
# 1                       2.12          144266                 1006.4
# 2                       4.12          119772                  411.0
# 3                       2.38           49985                  277.3
# 4                       2.75          624590                 1290.7
#
#    ebitda_margin_pct_latest  ebitda_margin_change_pctpts  sales_growth_pct  \
# 0                 11.379727                    -1.363707          8.602120
# 1                  9.266217                    -0.620966          6.169278
# 2                 14.583542                    -5.488198        -11.050708
# 3                 13.450035                    -2.298332          6.375960
# 4                 10.152580                    -0.404716         10.537121
#
#    ...                          inventory_days_est_source  \
# 0  ...  ABS quarterly inventories/sales ratio converte...
# 1  ...  Fallback inventory-days estimate derived from ...
# 2  ...  Fallback inventory-days estimate derived from ...
# 3  ...  Fallback inventory-days estimate derived from ...
# 4  ...  Fallback inventory-days estimate derived from ...
#
#    inventory_stock_build_risk  employment_score  margin_level_score  \
# 0                         Low                 4                   4
# 1                         Low                 2                   5
# 2                         Low                 5                   3
# 3                         Low                 5                   3
# 4                         Low                 3                   4
#
#    margin_trend_score  inventory_score demand_score  macro_risk_score  \
# 0                   3                1            1               2.6
# 1                   3                1            3               2.8
# 2                   5                2            1               3.2
# 3                   4                2            5               3.8
# 4                   3                2            1               2.6
#
#    industry_base_risk_score  industry_base_risk_level
# 0                      2.68                    Medium
# 1                      2.43                    Medium
# 2                      3.71                  Elevated
# 3                      3.02             Moderate-high
# 4                      2.68                    Medium
#
# [5 rows x 33 columns]
