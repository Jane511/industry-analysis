# %% [markdown]
# # 00 Repo Overview
#
# Purpose: orient new staff to the upstream public-data and overlay role of this repository.

# %%
import sys, pathlib
# Make the repo root importable whether run from repo root or notebooks/
_root = pathlib.Path.cwd()
if not (_root / 'src').exists() and (_root.parent / 'src').exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

from src.config import CONTRACTS_DIR
CONTRACTS_DIR
# Out:
# WindowsPath('D:/Jane/Job Search/Github/bank/github project/external benchmarks and industry analysis/industry-analysis/outputs/contracts')
